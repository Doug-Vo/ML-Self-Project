# %%
import kagglehub
rohitgrewal_airlines_flights_data_path = kagglehub.dataset_download('rohitgrewal/airlines-flights-data')

print('Data source import complete.')
# Out:
# Data source import complete.

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)


import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /kaggle/input/airlines-flights-data/airlines_flights_data.csv

# %%
df = pd.read_csv("/kaggle/input/airlines-flights-data/airlines_flights_data.csv")

df.head()
# Out:
#    index   airline   flight source_city departure_time stops   arrival_time  \
# 0      0  SpiceJet  SG-8709       Delhi        Evening  zero          Night
# 1      1  SpiceJet  SG-8157       Delhi  Early_Morning  zero        Morning
# 2      2   AirAsia   I5-764       Delhi  Early_Morning  zero  Early_Morning
# 3      3   Vistara   UK-995       Delhi        Morning  zero      Afternoon
# 4      4   Vistara   UK-963       Delhi        Morning  zero        Morning
#
#   destination_city    class  duration  days_left  price
# 0           Mumbai  Economy      2.17          1   5953
# 1           Mumbai  Economy      2.33          1   5953
# 2           Mumbai  Economy      2.17          1   5956
# 3           Mumbai  Economy      2.25          1   5955
# 4           Mumbai  Economy      2.33          1   5955

# %%
df.info()
df.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300153 entries, 0 to 300152
# Data columns (total 12 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   index             300153 non-null  int64
#  1   airline           300153 non-null  object
#  2   flight            300153 non-null  object
#  3   source_city       300153 non-null  object
#  4   departure_time    300153 non-null  object
#  5   stops             300153 non-null  object
#  6   arrival_time      300153 non-null  object
#  7   destination_city  300153 non-null  object
#  8   class             300153 non-null  object
#  9   duration          300153 non-null  float64
#  10  days_left         300153 non-null  int64
#  11  price             300153 non-null  int64
# dtypes: float64(1), int64(3), object(8)
# memory usage: 27.5+ MB
# index               0
# airline             0
# flight              0
# source_city         0
# departure_time      0
# ...

# %% [markdown]
# # Q.1. What are the airlines in the dataset, accompanied by their frequencies?

# %%
import seaborn as sns
import matplotlib.pyplot as plt

df['airline'].value_counts()

df['airline'].value_counts(ascending =True).plot.barh(color = ['lightblue', 'lightgreen'])

plt.title('Airlines and Their Frequencies', fontsize=16)
plt.xlabel('Count')
plt.ylabel('Airline')
plt.show()

# %% [markdown]
# # Q.2. Show Bar Graphs representing the Departure Time & Arrival Time.

# %%
for col in ['departure_time', 'arrival_time']:
    print(col)
    print(df[col].unique())
# Out:
# departure_time
# ['Evening' 'Early_Morning' 'Morning' 'Afternoon' 'Night' 'Late_Night']
# arrival_time
# ['Night' 'Morning' 'Early_Morning' 'Afternoon' 'Evening' 'Late_Night']

# %%
combined_counts = pd.DataFrame({
    'Departure': df['departure_time'].value_counts(),
    'Arrival': df['arrival_time'].value_counts()
})


combined_counts.plot.barh(
    figsize=(10, 7),
    color=['g', 'r'], # Set your colors
    width=0.8
)

plt.title('Departures vs. Arrivals by Time of Day', fontsize=16)
plt.xlabel('Count')
plt.ylabel('Time of Day')
plt.gca().invert_yaxis() # Flips the y-axis to show Early_Morning at the top
plt.tight_layout()
plt.show()

# %% [markdown]
# # Q.3. Show Bar Graphs representing the Source City & Destination City.

# %%
for col in ['source_city', 'destination_city']:
    print(col)
    print(df[col].unique())
# Out:
# source_city
# ['Delhi' 'Mumbai' 'Bangalore' 'Kolkata' 'Hyderabad' 'Chennai']
# destination_city
# ['Mumbai' 'Bangalore' 'Kolkata' 'Hyderabad' 'Chennai' 'Delhi']

# %%
combined_cities = pd.DataFrame({
    'source' : df['source_city'].value_counts(),
    'destination' : df ['destination_city'].value_counts()
})

ax = combined_cities.plot.bar(
    figsize = (10, 6),
    color = ['lightgreen', 'r']
)


plt.title('Source Cities vs Destination Cities', fontsize=16)
plt.xlabel('Count')
plt.ylabel('City')
plt.show()

# %% [markdown]
# # Q.4. Does price varies with airlines ?

# %%
df.groupby('airline')['price'].mean()
# Out:
# airline
# AirAsia       4091.072742
# Air_India    23507.019112
# GO_FIRST      5652.007595
# Indigo        5324.216303
# SpiceJet      6179.278881
# Vistara      30396.536302
# Name: price, dtype: float64

# %%
sns.catplot( x = 'airline', y = 'price', data = df, kind = 'bar', hue = 'class')
plt.show()

# %% [markdown]
# # Q.5. Does ticket price change based on the departure time and arrival time?

# %%
plt.figure(figsize = (15, 4))

sns.catplot(x = 'departure_time', y = 'price', data = df, kind = 'bar')
plt.title('Price based on depature time')
plt.show()

# %%
sns.catplot(x = 'arrival_time', y = 'price', data = df, kind = 'bar')
plt.title('Price based on arrival time')
plt.show()

# %% [markdown]
# # Q.6. How the price changes with change in Source and Destination?

# %%
plt.figure(figsize = (10, 12))


sns.catplot(x = 'source_city', y = 'price', data = df, kind = 'bar')
plt.title('Price based on Source City')

plt.show()

# %%
sns.catplot(x = 'destination_city', y = 'price', data = df, kind = 'bar')
plt.title('Price based on Destination City')

plt.show()

# %%
sns.relplot(data = df, x = 'source_city', y = 'price', col = 'destination_city', kind = 'line', col_wrap =3)
plt.show()

# %% [markdown]
# # Q.7. How is the price affected when tickets are bought in just 1 or 2 days before departure?

# %%
plt.figure(figsize=(16, 7))

unique_days = sorted(df['days_left'].unique())
palette = ['red' if day <= 2 else 'steelblue' for day in unique_days]

sns.barplot(
    data=df,
    x='days_left',
    y='price',
    palette=palette,
)

plt.title('Average Price by Days Left to Departure')
plt.show()
# Out:
# /tmp/ipython-input-4128214665.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(

# %% [markdown]
# # Q.8. How does the ticket price vary between Economy and Business class?

# %%
sns.barplot(
    data = df,
    y = 'price',
    x = 'airline',
    hue = 'class',
)

plt.show()

# %% [markdown]
# # Q.9. What will be the Average Price of Vistara airline for a flight from Delhi to Hyderabad in Business Class ?

# %%
check_data = df[( (df['airline'] == 'Vistara') & (df['source_city'] == 'Delhi') &
                 (df ['destination_city'] == 'Hyderabad') & (df['class'] == 'Business'))]



price = check_data['price'].mean()

print('Average Price: ' + str(price))
# Out:
# Average Price: 47939.840361445786
